# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# check how long unpack is needed
# !date
# !tar -xf /content/drive/My\ Drive/conda_colab.tar.gz -C ../
# !date
# takes 4 mins

import os
path = '/content/miniconda3/bin:' + os.environ['PATH']
# %env PATH=$path
# %env PYTHONPATH=
import sys
_ = sys.path.append("/content/miniconda3/lib/python3.7/site-packages")
# Out:
# Mon Nov 22 21:22:46 UTC 2021
# Mon Nov 22 21:26:22 UTC 2021
# env: PATH=/content/miniconda3/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin
# env: PYTHONPATH=

# %%
# check if the environment is properly installed and save and reload?
# %cd /content/drive/MyDrive/HME/PoseFormer-main/

! conda env create -f poseformer.yml
! conda info --envs

# ! source activate pose2 && pip install numpy --upgrade
# Out:
# /content/drive/MyDrive/HME/PoseFormer-main
#
# CondaValueError: prefix already exists: /content/miniconda3/envs/pose2
#
# # conda environments:
# #
# base                  *  /content/miniconda3
# pose2                    /content/miniconda3/envs/pose2

# %% [markdown]
# When trying to create an environment called pose2, it shows "the prefix already exists", which proves the environment has been properly saved and reloaded!
